# %%
import cv2
import numpy as np

# Load the image
img = cv2.imread('C:/Users/parit/Downloads/ast_sci_data_tables_sample_page_1.png')

# Convert the image to grayscale
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

# Apply thresholding to the image
thresh = cv2.threshold(gray, 0, 255, cv2.THRESH_BINARY_INV + cv2.THRESH_OTSU)[1]

# Find contours in the image
contours, hierarchy = cv2.findContours(thresh, cv2.RETR_TREE, cv2.CHAIN_APPROX_SIMPLE)

# Find the largest contour (the table)
max_area = 0
table_contour = None
for contour in contours:
    area = cv2.contourArea(contour)
    if area > max_area:
        max_area = area
        table_contour = contour

# Create a mask of the same size as the input image
mask = np.zeros_like(img)

# Draw the contour on the mask
cv2.drawContours(mask, [table_contour], -1, (255, 255, 255), -1)

# Invert the mask
mask_inv = cv2.bitwise_not(mask)

# Use the mask to remove the table from the input image
img_no_table = cv2.bitwise_and(img, mask_inv)

# Save the result image
cv2.imwrite('image_without_table.jpg', img_no_table)

# Display the result
cv2.imshow('Image without table', img_no_table)
cv2.waitKey(0)
# Out:
# -1

# %%
import pytesseract
pytesseract.pytesseract.tesseract_cmd=r'C:\Program Files\Tesseract-OCR\tesseract.exe'
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-2-b51c997afba5> in <module>
# ----> 1 import pytesseract
#       2 pytesseract.pytesseract.tesseract_cmd=r'C:\Program Files\Tesseract-OCR\tesseract.exe'
#
# ModuleNotFoundError: No module named 'pytesseract'

# %%
import cv2

# %%
img = cv2.imread('image_without_table.jpg')
cv2.imshow('Sample image3',img)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
text=pytesseract.image_to_string(img)
print(text)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-ab0309795bf8> in <module>
# ----> 1 text=pytesseract.image_to_string(img)
#       2 print(text)
#
# NameError: name 'pytesseract' is not defined

# %%
import cv2
import pytesseract

# Load the image and convert it to grayscale
image = cv2.imread('image_without_table.jpg')
gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

# Apply thresholding to binarize the image
_, thresh = cv2.threshold(gray, 0, 255, cv2.THRESH_BINARY_INV | cv2.THRESH_OTSU)

# Perform OCR on the image using pytesseract
ocr_output = pytesseract.image_to_data(thresh, output_type=pytesseract.Output.DICT)

# Parse the OCR output to identify page numbers
page_numbers = []
for i in range(len(ocr_output['text'])):
    text = ocr_output['text'][i].strip()
    if text.isdigit() and int(text) >= 2 and int(text) <= 100:
        x = ocr_output['left'][i]
        y = ocr_output['top'][i]
        w = ocr_output['width'][i]
        h = ocr_output['height'][i]
        page_numbers.append((x, y, w, h, text))

# Use OpenCV to draw black rectangles over the page numbers to remove them
for (x, y, w, h, text) in page_numbers:
    cv2.rectangle(image, (x, y), (x + w, y + h), (0, 0, 0), -1)

# Save the output image
cv2.imwrite('output1111.jpg', image)

# Display the output image
cv2.imshow('Output', image)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
import cv2
import pytesseract

# Load the image and convert it to grayscale
image = cv2.imread('image_without_table.jpg')
gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

# Apply thresholding to binarize the image
_, thresh = cv2.threshold(gray, 0, 255, cv2.THRESH_BINARY_INV | cv2.THRESH_OTSU)

# Perform OCR on the image using pytesseract
ocr_output = pytesseract.image_to_data(thresh, output_type=pytesseract.Output.DICT)

# Parse the OCR output to identify page numbers
page_numbers = []
for i in range(len(ocr_output['text'])):
    text = ocr_output['text'][i].strip()
    if text.isdigit() and int(text) >= 2 and int(text) <= 100:
        x = ocr_output['left'][i]
        y = ocr_output['top'][i]
        w = ocr_output['width'][i]
        h = ocr_output['height'][i]
        page_numbers.append((x, y, w, h, text))

# Use OpenCV to draw black rectangles over the page numbers to remove them
for (x, y, w, h, text) in page_numbers:
    cv2.rectangle(image, (x, y), (x + w, y + h), (0, 0, 0), -1)

# Save the output image
cv2.imwrite('output.jpg', image)

# Display the output image
cv2.imshow('Output', image)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
pip install pytesseract
# Out:
# ...
#   Using cached pytesseract-0.3.10-py3-none-any.whl (14 kB)
# ...
#   Attempting uninstall: packaging
#     Found existing installation: packaging 20.4
#     Uninstalling packaging-20.4:
#       Successfully uninstalled packaging-20.4
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pytesseract

# %%
import cv2

# %%
img = cv2.imread('image_without_table.jpg')
cv2.imshow('Sample image3',img)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
text=pytesseract.image_to_string(img)
print(text)
# Out:
# NATIONAL PARTNERSHIP FOR QUALITY AFTERSCHOOL LEARNING
# www.sedl.org/afterschool/toolkits
#
# AFTERSCHOOL TRAINING TOOLKIT
#
# Tutoring to Enhance Science Skills
# Tutoring Two: Learning to Make Data Tables
#
# Sample Data for Data Tables
#
# Use these data to create data tables following the Guidelines for Making a Data Table and
# Checklist for a Data Table.
#
# Example 1: Pet Survey (GR 2-3)
# Ms. Hubert’s afterschool students took a survey of the 600 students at Morales Elementary
# School. Students were asked to select their favorite pet from a list of eight animals. Here
# are the results.
#
# Lizard 25, Dog 250, Cat 115, Bird 50, Guinea pig 30, Hamster 45, Fish 75,
#
# Ferret 10
#
# Example 2: Electromagnets—Increasing Coils (GR 3-5)
#
# The following data were collected using an electromagnet with a 1.5 volt battery, a switch,
# a piece of #20 insulated wire, and a nail. Three trials were run. Safety precautions in
# ...

# %%
import cv2
import pytesseract

# Load the image and convert it to grayscale
image = cv2.imread('image_without_table.jpg')
gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

# Apply thresholding to binarize the image
_, thresh = cv2.threshold(gray, 0, 255, cv2.THRESH_BINARY_INV | cv2.THRESH_OTSU)

# Perform OCR on the image using pytesseract
ocr_output = pytesseract.image_to_data(thresh, output_type=pytesseract.Output.DICT)

# Parse the OCR output to identify page numbers
page_numbers = []
for i in range(len(ocr_output['text'])):
    text = ocr_output['text'][i].strip()
    if text.isdigit() and int(text) >= 2 and int(text) <= 100:
        x = ocr_output['left'][i]
        y = ocr_output['top'][i]
        w = ocr_output['width'][i]
        h = ocr_output['height'][i]
        page_numbers.append((x, y, w, h, text))

# Use OpenCV to draw black rectangles over the page numbers to remove them
for (x, y, w, h, text) in page_numbers:
    cv2.rectangle(image, (x, y), (x + w, y + h), (0, 0, 0), -1)

# Save the output image
cv2.imwrite('output.jpg', image)

# Display the output image
cv2.imshow('Output', image)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
import cv2
import pytesseract

# Load the image and convert it to grayscale
image = cv2.imread('image_without_table.jpg')
gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

# Apply thresholding to binarize the image
_, thresh = cv2.threshold(gray, 0, 255, cv2.THRESH_BINARY_INV | cv2.THRESH_OTSU)

# Perform OCR on the image using pytesseract
ocr_output = pytesseract.image_to_data(thresh, output_type=pytesseract.Output.DICT)

# Parse the OCR output to identify page numbers
page_numbers = []
for i in range(len(ocr_output['text'])):
    text = ocr_output['text'][i].strip()
    if text.isdigit() and int(text) >= 2 and int(text) <= 100:
        # Check if the page number is at the bottom of the image
        if ocr_output['top'][i] > (image.shape[0] - 100):
            x = ocr_output['left'][i]
            y = ocr_output['top'][i]
            w = ocr_output['width'][i]
            h = ocr_output['height'][i]
            page_numbers.append((x, y, w, h, text))

# Use OpenCV to draw black rectangles over the page numbers to remove them
for (x, y, w, h, text) in page_numbers:
    cv2.rectangle(image, (x, y), (x + w, y + h), (0, 0, 0), -1)

# Save the output image
cv2.imwrite('output22.jpg', image)

# Display the output image
cv2.imshow('Output', image)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
import cv2
import pytesseract

# Load the image and convert it to grayscale
image = cv2.imread('image_without_table.jpg')
gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

# Apply thresholding to binarize the image
_, thresh = cv2.threshold(gray, 0, 255, cv2.THRESH_BINARY_INV | cv2.THRESH_OTSU)

# Perform OCR on the image using pytesseract
ocr_output = pytesseract.image_to_data(thresh, output_type=pytesseract.Output.DICT)

# Parse the OCR output to identify page numbers
page_numbers = []
for i in range(len(ocr_output['text'])):
    text = ocr_output['text'][i].strip()
    if text.isdigit() and int(text) >= 2 and int(text) <= 100:
        # Check if the page number is at the bottom of the image
        if ocr_output['top'][i] > (image.shape[0] - 100):
            x = ocr_output['left'][i]
            y = ocr_output['top'][i]
            w = ocr_output['width'][i]
            h = ocr_output['height'][i]
            page_numbers.append((x, y, w, h))

# Use OpenCV to draw white rectangles over the page numbers to remove them
for (x, y, w, h) in page_numbers:
    cv2.rectangle(image, (x, y), (x + w, y + h), (255, 255, 255), -1)

# Save the output image
cv2.imwrite('output23.jpg', image)

# Display the output image
cv2.imshow('Output', image)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
import cv2
import numpy as np
import pytesseract

# Load the image and convert it to grayscale
image = cv2.imread('image_without_table.jpg')
gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

# Apply thresholding to binarize the image
_, thresh = cv2.threshold(gray, 0, 255, cv2.THRESH_BINARY_INV | cv2.THRESH_OTSU)

# Perform OCR on the image using pytesseract
ocr_output = pytesseract.image_to_data(thresh, output_type=pytesseract.Output.DICT)

# Parse the OCR output to identify page numbers
page_numbers = []
for i in range(len(ocr_output['text'])):
    text = ocr_output['text'][i].strip()
    if text.isdigit() and int(text) >= 2 and int(text) <= 100:
        # Check if the page number is at the bottom of the image
        if ocr_output['top'][i] > (image.shape[0] - 100):
            x = ocr_output['left'][i]
            y = ocr_output['top'][i]
            w = ocr_output['width'][i]
            h = ocr_output['height'][i]
            page_numbers.append((x, y, w, h))

# Create a mask with the same size as the image, initialized to white
mask = np.ones(image.shape[:2], dtype="uint8") * 255

# Use OpenCV to draw black rectangles over the page numbers in the mask
for (x, y, w, h) in page_numbers:
    cv2.rectangle(mask, (x, y), (x + w, y + h), 0, -1)

# Apply the mask to the original image to remove the page numbers
result = cv2.bitwise_and(image, image, mask=mask)

# Save the output image
cv2.imwrite('output24.jpg', result)

# Display the output image
cv2.imshow('Output', result)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
import cv2
import numpy as np
import pytesseract

# Load the image and convert it to grayscale
image = cv2.imread('image_without_table.jpg')
gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

# Apply thresholding to binarize the image
_, thresh = cv2.threshold(gray, 0, 255, cv2.THRESH_BINARY_INV | cv2.THRESH_OTSU)

# Perform OCR on the image using pytesseract
ocr_output = pytesseract.image_to_data(thresh, output_type=pytesseract.Output.DICT)

# Parse the OCR output to identify page numbers
page_numbers = []
for i in range(len(ocr_output['text'])):
    text = ocr_output['text'][i].strip()
    if text.isdigit() and int(text) >= 2 and int(text) <= 100:
        # Check if the page number is at the bottom of the image
        if ocr_output['top'][i] > (image.shape[0] - 100):
            x = ocr_output['left'][i]
            y = ocr_output['top'][i]
            w = ocr_output['width'][i]
            h = ocr_output['height'][i]
            page_numbers.append((x, y, w, h))

# Create a copy of the original image
result = image.copy()

# Use OpenCV to draw black rectangles over the page numbers in the copy of the image
for (x, y, w, h) in page_numbers:
    cv2.rectangle(result, (x, y), (x + w, y + h), (0, 0, 0), -1)

# Save the output image
cv2.imwrite('output25.jpg', result)

# Display the output image
cv2.imshow('Output', result)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
import cv2
import numpy as np
import pytesseract

# Load the image and convert it to grayscale
image = cv2.imread('image_without_table.jpg')
gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

# Apply thresholding to binarize the image
_, thresh = cv2.threshold(gray, 0, 255, cv2.THRESH_BINARY_INV | cv2.THRESH_OTSU)

# Perform OCR on the image using pytesseract
ocr_output = pytesseract.image_to_data(thresh, output_type=pytesseract.Output.DICT)

# Parse the OCR output to identify page numbers
page_numbers = []
for i in range(len(ocr_output['text'])):
    text = ocr_output['text'][i].strip()
    if text.isdigit() and int(text) >= 2 and int(text) <= 100:
        # Check if the page number is at the bottom of the image
        if ocr_output['top'][i] > (image.shape[0] - 100):
            x = ocr_output['left'][i]
            y = ocr_output['top'][i]
            w = ocr_output['width'][i]
            h = ocr_output['height'][i]
            page_numbers.append((x, y, w, h))

# Create a copy of the original image
result = image.copy()

# Use OpenCV to draw black rectangles over the page numbers in the copy of the image
for (x, y, w, h) in page_numbers:
    cv2.rectangle(result, (x, y), (x + w, y + h), (0, 0, 0), -1)

# Save the output image
cv2.imwrite('output27.jpg', result)

# Display the output image
cv2.imshow('Output', result)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
import cv2
import numpy as np
import pytesseract

# Load the image and convert it to grayscale
image = cv2.imread('image_without_table.jpg')
gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

# Apply thresholding to binarize the image
_, thresh = cv2.threshold(gray, 0, 255, cv2.THRESH_BINARY_INV | cv2.THRESH_OTSU)

# Perform OCR on the image using pytesseract
ocr_output = pytesseract.image_to_data(thresh, output_type=pytesseract.Output.DICT)

# Parse the OCR output to identify page numbers
page_numbers = []
for i in range(len(ocr_output['text'])):
    text = ocr_output['text'][i].strip()
    if text.isdigit() and int(text) >= 2 and int(text) <= 100:
        # Check if the page number is at the bottom of the image
        if ocr_output['top'][i] > (image.shape[0] - 100):
            x = ocr_output['left'][i]
            y = ocr_output['top'][i]
            w = ocr_output['width'][i]
            h = ocr_output['height'][i]
            page_numbers.append((x, y, w, h))

# Create a copy of the original image
result = image.copy()

# Use numpy to create a mask for the identified page numbers
mask = np.zeros_like(gray)
for (x, y, w, h) in page_numbers:
    mask[y:y+h, x:x+w] = 255

# Use the mask to mask the page numbers in the copy of the image
result[mask == 255] = [0, 0, 0]

# Save the output image
cv2.imwrite('output28.jpg', result)

# Display the output image
cv2.imshow('Output', result)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
import cv2
import numpy as np
import pytesseract

# Load the image and convert it to grayscale
image = cv2.imread('image_without_table.jpg')
gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

# Apply thresholding to binarize the image
_, thresh = cv2.threshold(gray, 0, 255, cv2.THRESH_BINARY_INV | cv2.THRESH_OTSU)

# Perform OCR on the image using pytesseract
ocr_output = pytesseract.image_to_data(thresh, output_type=pytesseract.Output.DICT)

# Parse the OCR output to identify page numbers
page_numbers = []
for i in range(len(ocr_output['text'])):
    text = ocr_output['text'][i].strip()
    if text.isdigit() and int(text) >= 2 and int(text) <= 100:
        # Check if the page number is at the bottom of the image
        if ocr_output['top'][i] > (image.shape[0] - 100):
            x = ocr_output['left'][i]
            y = ocr_output['top'][i]
            w = ocr_output['width'][i]
            h = ocr_output['height'][i]
            page_numbers.append((x, y, w, h))

# Create a copy of the original image
result = image.copy()

# Use numpy to create a mask for the identified page numbers
mask = np.zeros_like(gray)
for (x, y, w, h) in page_numbers:
    mask[y:y+h, x:x+w] = 255

# Use the mask to mask the page numbers in the copy of the image
result[mask == 255] = (0, 0, 0)

# Save the output image
cv2.imwrite('output32.jpg', result)

# Display the output image
cv2.imshow('Output', result)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
import cv2
import numpy as np
import pytesseract

# Load the image and convert it to grayscale
image = cv2.imread('image_without_table.jpg')
gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

# Apply thresholding to binarize the image
_, thresh = cv2.threshold(gray, 0, 255, cv2.THRESH_BINARY_INV | cv2.THRESH_OTSU)

# Perform OCR on the image using pytesseract
ocr_output = pytesseract.image_to_data(thresh, output_type=pytesseract.Output.DICT)

# Parse the OCR output to identify page numbers
page_numbers = []
for i in range(len(ocr_output['text'])):
    text = ocr_output['text'][i].strip()
    if text.isdigit() and int(text) >= 2 and int(text) <= 100:
        # Check if the page number is at the bottom of the image
        if ocr_output['top'][i] > (image.shape[0] - 150):
            x = ocr_output['left'][i]
            y = ocr_output['top'][i]
            w = ocr_output['width'][i]
            h = ocr_output['height'][i]
            page_numbers.append((x, y, w, h))

# Create a copy of the original image
result = image.copy()

# Use numpy to create a mask for the identified page numbers
mask = np.zeros_like(gray)
for (x, y, w, h) in page_numbers:
    mask[y:y+h, x:x+w] = 255

# Use the mask to mask the page numbers in the copy of the image
result[mask == 255] = (0, 0, 0)

# Save the output image
cv2.imwrite('output33.jpg', result)

# Display the output image
cv2.imshow('Output', result)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
import cv2

# Load the image and convert it to grayscale
image = cv2.imread('image_without_table.jpg')
gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

# Apply thresholding to binarize the image
_, thresh = cv2.threshold(gray, 0, 255, cv2.THRESH_BINARY_INV | cv2.THRESH_OTSU)

# Find contours in the image
contours, hierarchy = cv2.findContours(thresh, cv2.RETR_TREE, cv2.CHAIN_APPROX_SIMPLE)

# Find the largest contour at the bottom of the image, which should correspond to the page number
max_area = 0
max_contour = None
for contour in contours:
    x, y, w, h = cv2.boundingRect(contour)
    if y + h > image.shape[0] - 10 and cv2.contourArea(contour) > max_area:
        max_area = cv2.contourArea(contour)
        max_contour = contour

# Fill the contour with black to mask the page number
if max_contour is not None:
    cv2.drawContours(image, [max_contour], 0, (0, 0, 0), -1)

# Save the output image
cv2.imwrite('output35.jpg', image)

# Display the output image
cv2.imshow('Output', image)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
import cv2
import pytesseract

# Load the image and convert it to grayscale
image = cv2.imread('image_without_table.jpg')
gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

# Apply thresholding to binarize the image
_, thresh = cv2.threshold(gray, 0, 255, cv2.THRESH_BINARY_INV | cv2.THRESH_OTSU)

# Perform OCR on the image using pytesseract
ocr_output = pytesseract.image_to_data(thresh, output_type=pytesseract.Output.DICT)

# Parse the OCR output to identify page numbers
page_numbers = []
for i in range(len(ocr_output['text'])):
    text = ocr_output['text'][i].strip()
    if text.isdigit() and int(text) >= 2 and int(text) <= 100:
        x = ocr_output['left'][i]
        y = ocr_output['top'][i]
        w = ocr_output['width'][i]
        h = ocr_output['height'][i]
        page_numbers.append((x, y, w, h, text))

# Use OpenCV to draw black rectangles over the page numbers to remove them
for (x, y, w, h, text) in page_numbers:
    cv2.rectangle(image, (x, y), (x + w, y + h), (0, 0, 0), -1)

# Save the output image
cv2.imwrite('output.jpg', image)

# Display the output image
cv2.imshow('Output', image)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
import cv2
import pytesseract

# Load the image and convert it to grayscale
image = cv2.imread('image_without_table.jpg')
gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

# Apply thresholding to binarize the image
_, thresh = cv2.threshold(gray, 0, 255, cv2.THRESH_BINARY_INV | cv2.THRESH_OTSU)

# Perform OCR on the image using pytesseract
ocr_output = pytesseract.image_to_data(thresh, output_type=pytesseract.Output.DICT)

# Parse the OCR output to identify page numbers
page_numbers = []
for i in range(len(ocr_output['text'])):
    text = ocr_output['text'][i].strip()
    if text.isdigit() and int(text) >= 2 and int(text) <= 100:
        x = ocr_output['left'][i]
        y = ocr_output['top'][i]
        w = ocr_output['width'][i]
        h = ocr_output['height'][i]
        page_numbers.append((x, y, w, h))

# Use OpenCV to draw black rectangles over the page numbers to remove them
for (x, y, w, h) in page_numbers:
    cv2.rectangle(image, (x, y), (x + w, y + h), (0, 0, 0), -1)

# Save the output image
cv2.imwrite('output_no_pagenumber.jpg', image)

# Display the output image
cv2.imshow('Output', image)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
import cv2
import pytesseract

# Load the image and convert it to grayscale
image = cv2.imread('image_without_table.jpg', cv2.IMREAD_UNCHANGED)
gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

# Apply thresholding to binarize the image
_, thresh = cv2.threshold(gray, 0, 255, cv2.THRESH_BINARY_INV | cv2.THRESH_OTSU)

# Perform OCR on the image using pytesseract
ocr_output = pytesseract.image_to_data(thresh, output_type=pytesseract.Output.DICT)

# Parse the OCR output to identify page numbers
page_numbers = []
for i in range(len(ocr_output['text'])):
    text = ocr_output['text'][i].strip()
    if text.isdigit() and int(text) >=2 and int(text) <= 80:
        x = ocr_output['left'][i]
        y = ocr_output['top'][i]
        w = ocr_output['width'][i]
        h = ocr_output['height'][i]
        page_numbers.append((x, y, w, h))

# Use OpenCV to draw black rectangles over the page numbers to remove them
for (x, y, w, h) in page_numbers:
    cv2.rectangle(image, (x, y), (x + w, y + h), (0, 0, 0), -1)

# Save the output image
cv2.imwrite('output_no_pagenumber38.jpg', image)

# Display the output image
cv2.imshow('Output', image)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
import cv2
import pytesseract

# Load the image
image = cv2.imread('image_without_table.jpg')

# Crop the image to remove the page number
crop = image[0:1250, 0:2400]

# Convert the cropped image to grayscale
gray = cv2.cvtColor(crop, cv2.COLOR_BGR2GRAY)

# Apply thresholding to binarize the image
_, thresh = cv2.threshold(gray, 0, 255, cv2.THRESH_BINARY_INV | cv2.THRESH_OTSU)

# Perform OCR on the image using pytesseract
ocr_output = pytesseract.image_to_data(thresh, output_type=pytesseract.Output.DICT)

# Parse the OCR output to extract the text and its position
text_positions = []
for i in range(len(ocr_output['text'])):
    text = ocr_output['text'][i].strip()
    if text:
        x = ocr_output['left'][i]
        y = ocr_output['top'][i]
        w = ocr_output['width'][i]
        h = ocr_output['height'][i]
        text_positions.append((text, x, y, w, h))

# Draw rectangles around the text on the original image
for (text, x, y, w, h) in text_positions:
    cv2.rectangle(image, (x, y), (x + w, y + h), (0, 0, 255), 2)
    cv2.putText(image, text, (x, y - 10), cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 0, 255), 2)

# Save the output image
cv2.imwrite('output41.jpg', image)

# Display the output image
cv2.imshow('Output', image)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
import cv2
import pytesseract

# Load the image and convert it to grayscale
image = cv2.imread('image_without_table.jpg')
gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

# Apply thresholding to binarize the image
_, thresh = cv2.threshold(gray, 0, 255, cv2.THRESH_BINARY_INV | cv2.THRESH_OTSU)

# Perform OCR on the image using pytesseract
ocr_output = pytesseract.image_to_data(thresh, output_type=pytesseract.Output.DICT)

# Parse the OCR output to identify page numbers
page_numbers = []
for i in range(len(ocr_output['text'])):
    text = ocr_output['text'][i].strip()
    if text.isdigit() and int(text) >= 2 and int(text) <= 100:
        x = ocr_output['left'][i]
        y = ocr_output['top'][i]
        w = ocr_output['width'][i]
        h = ocr_output['height'][i]
        page_numbers.append((x, y, w, h))

# Find the largest page number in the bottom half of the image
bottom_half = thresh[int(thresh.shape[0]/2):, :]
bottom_ocr_output = pytesseract.image_to_data(bottom_half, output_type=pytesseract.Output.DICT)
bottom_page_numbers = []
for i in range(len(bottom_ocr_output['text'])):
    text = bottom_ocr_output['text'][i].strip()
    if text.isdigit() and int(text) >= 2 and int(text) <= 100:
        x = bottom_ocr_output['left'][i]
        y = bottom_ocr_output['top'][i] + int(thresh.shape[0]/2)
        w = bottom_ocr_output['width'][i]
        h = bottom_ocr_output['height'][i]
        bottom_page_numbers.append((x, y, w, h))
largest_page_number = max(bottom_page_numbers, key=lambda x: x[2]) if bottom_page_numbers else None

# Use OpenCV to draw black rectangles over the page numbers to remove them
if largest_page_number:
    (x, y, w, h) = largest_page_number
    cv2.rectangle(image, (x, y), (x + w, y + h), (0, 0, 0), -1)

# Save the output image
cv2.imwrite('output45.jpg', image)

# Display the output image
cv2.imshow('Output', image)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
import cv2
import pytesseract

# Load the image and convert it to grayscale
image = cv2.imread('image_without_table.jpg')
gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

# Crop out the bottom part of the image containing the page number
height, width = gray.shape[:2]
crop_img = gray[0:height-100, 0:width]

# Apply thresholding to binarize the image
_, thresh = cv2.threshold(crop_img, 0, 255, cv2.THRESH_BINARY_INV | cv2.THRESH_OTSU)

# Perform OCR on the image using pytesseract
ocr_output = pytesseract.image_to_data(thresh, output_type=pytesseract.Output.DICT)

# Parse the OCR output to identify page numbers
page_numbers = []
for i in range(len(ocr_output['text'])):
    text = ocr_output['text'][i].strip()
    if text.isdigit() and int(text) >= 2 and int(text) <= 100:
        x = ocr_output['left'][i]
        y = ocr_output['top'][i]
        w = ocr_output['width'][i]
        h = ocr_output['height'][i]
        page_numbers.append((x, y, w, h))

# Use OpenCV to draw black rectangles over the page numbers to remove them
for (x, y, w, h) in page_numbers:
    cv2.rectangle(crop_img, (x, y), (x + w, y + h), (0, 0, 0), -1)

# Save the output image
cv2.imwrite('output_no_pagenumber48.jpg', crop_img)

# Display the output image
cv2.imshow('Output', crop_img)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
import cv2
import pytesseract

# Load the image and convert it to grayscale
image = cv2.imread('image_without_table.jpg')
gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

# Apply thresholding to binarize the image
_, thresh = cv2.threshold(gray, 0, 255, cv2.THRESH_BINARY_INV | cv2.THRESH_OTSU)

# Perform OCR on the image using pytesseract
ocr_output = pytesseract.image_to_data(thresh, output_type=pytesseract.Output.DICT)

# Parse the OCR output to identify page numbers
page_numbers = []
for i in range(len(ocr_output['text'])):
    text = ocr_output['text'][i].strip()
    if text.isdigit() and int(text) >= 2 and int(text) <= 100:
        x = ocr_output['left'][i]
        y = ocr_output['top'][i]
        w = ocr_output['width'][i]
        h = ocr_output['height'][i]
        page_numbers.append((x, y, w, h))

# Use OpenCV to draw black rectangles over the page numbers to remove them
for (x, y, w, h) in page_numbers:
    # Check if the page number is at the bottom of the image
    if y + h >= image.shape[0] - 10:
        # If the page number is at the bottom, remove it by filling it with black color
        cv2.rectangle(image, (x, y), (x + w, y + h), (0, 0, 0), -1)
    else:
        # If the page number is not at the bottom, draw a black rectangle over it
        cv2.rectangle(image, (x, y), (x + w, y + h), (0, 0, 0), -1)

# Save the output image
cv2.imwrite('output_no_pagenumber49.jpg', image)

# Display the output image
cv2.imshow('Output', image)
cv2.waitKey(0)
cv2.destroyAllWindows()
